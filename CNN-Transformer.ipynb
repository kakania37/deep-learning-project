# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv1D, MaxPooling1D, Dropout, Flatten, Dense,
    LSTM, LayerNormalization, Add
)
import matplotlib.pyplot as plt

# 1. 下载股票数据
ticker = 'AAPL'

data = yf.download(ticker, start='2010-01-01', end='2023-01-01')
data = data[['Open', 'High', 'Low', 'Close']]  # Selecting the necessary columns


# 2. 数据预处理
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# 3. 创建数据集
def create_dataset(data, time_step=60):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), :])  # 使用所有特征
        y.append(data[i + time_step, -1])  # 预测收盘价
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# 划分训练集和测试集
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 4. 构建 CNN + LSTM 模型
input_layer = Input(shape=(time_step, X.shape[2]))

# 第一层卷积
x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(input_layer)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x)

# 第二层卷积
x = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same')(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x)

# LSTM 层
x = LSTM(50, activation='relu', return_sequences=False)(x)

# 全连接层
x = Dense(50, activation='relu', kernel_regularizer='l2')(x)
x = Dropout(0.3)(x)
output_layer = Dense(1)(x)

# 定义模型
model = Model(inputs=input_layer, outputs=output_layer)

# 编译模型
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mean_squared_error')

# 5. 训练模型
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# 6. 预测
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# 反归一化
train_predict_inv = scaler.inverse_transform(np.concatenate((X_train[:, -1, :-1], train_predict), axis=1))[:, -1]
test_predict_inv = scaler.inverse_transform(np.concatenate((X_test[:, -1, :-1], test_predict), axis=1))[:, -1]
y_train_inv = scaler.inverse_transform(np.concatenate((X_train[:, -1, :-1], y_train.reshape(-1, 1)), axis=1))[:, -1]
y_test_inv = scaler.inverse_transform(np.concatenate((X_test[:, -1, :-1], y_test.reshape(-1, 1)), axis=1))[:, -1]

# 计算误差指标
train_mae = mean_absolute_error(y_train_inv, train_predict_inv)
test_mae = mean_absolute_error(y_test_inv, test_predict_inv)
train_mse = mean_squared_error(y_train_inv, train_predict_inv)
test_mse = mean_squared_error(y_test_inv, test_predict_inv)
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)
train_r2 = r2_score(y_train_inv, train_predict_inv)
test_r2 = r2_score(y_test_inv, test_predict_inv)

# 输出评估结果
print(f'Train MAE: {train_mae:.4f}, Train MSE: {train_mse:.4f}, Train RMSE: {train_rmse:.4f}, Train R²: {train_r2:.4f}')
print(f'Test MAE: {test_mae:.4f}, Test MSE: {test_mse:.4f}, Test RMSE: {test_rmse:.4f}, Test R²: {test_r2:.4f}')

# 保存评估指标
output_text = f'''
Train MAE: {train_mae:.4f}, Train MSE: {train_mse:.4f}, Train RMSE: {train_rmse:.4f}, Train R²: {train_r2:.4f}
Test MAE: {test_mae:.4f}, Test MSE: {test_mse:.4f}, Test RMSE: {test_rmse:.4f}, Test R²: {test_r2:.4f}
'''

# 使用 UTF-8 编码保存评估结果
with open('evaluation_metrics(CNN-Transformer).txt', 'w', encoding='utf-8') as f:
    f.write(output_text)

# 7. 可视化损失曲线
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('loss_plot(CNN-Transformer).png')
plt.show()

# 8. 可视化训练和测试集的预测结果
plt.figure(figsize=(12, 6))

# 训练集的实际值和预测值
plt.plot(np.arange(len(y_train_inv)), y_train_inv, label='Actual Price (Train)', color='blue')
plt.plot(np.arange(len(y_train_inv)), train_predict_inv, label='Predicted Price (Train)', color='cyan')

# 测试集的实际值和预测值
plt.plot(np.arange(len(y_train_inv), len(y_train_inv) + len(y_test_inv)), y_test_inv, label='Actual Price (Test)', color='green')
plt.plot(np.arange(len(y_train_inv), len(y_train_inv) + len(y_test_inv)), test_predict_inv, label='Predicted Price (Test)', color='red')

plt.title('Stock Price Prediction (Train & Test)')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# 保存并显示图像
plt.savefig('prediction_plot(CNN-Transformer).png')
plt.show()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.5077 - val_loss: 0.5181
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4535 - val_loss: 0.4519
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4103 - val_loss: 0.4075
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3707 - val_loss: 0.3659
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3347 - val_loss: 0.3436
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3021 - val_loss: 0.3030
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2721 - val_loss: 0.2880
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2449 - val_loss: 0.2511
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2201 - val_loss: 0.2276
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1975 - val_loss: 0.1976
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1769 - val_loss: 0.1798
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1582 - val_loss: 0.1683
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1412 - val_loss: 0.1479
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1259 - val_loss: 0.1328
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1119 - val_loss: 0.1151
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0993 - val_loss: 0.1055
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0879 - val_loss: 0.0906
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0777 - val_loss: 0.0813
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0685 - val_loss: 0.0719
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0601 - val_loss: 0.0638
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0528 - val_loss: 0.0615
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0462 - val_loss: 0.0506
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0402 - val_loss: 0.0433
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0349 - val_loss: 0.0373
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0303 - val_loss: 0.0325
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0262 - val_loss: 0.0287
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0225 - val_loss: 0.0249
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0193 - val_loss: 0.0212
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0167 - val_loss: 0.0186
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0141 - val_loss: 0.0166
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0163
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0102 - val_loss: 0.0206
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0086 - val_loss: 0.0161
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0074 - val_loss: 0.0120
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0062 - val_loss: 0.0109
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0051 - val_loss: 0.0345
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0043 - val_loss: 0.0222
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0036 - val_loss: 0.0302
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0031 - val_loss: 0.0437
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0026 - val_loss: 0.0433
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.1070
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0489
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0933
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 0.0795
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.1234
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4895e-04 - val_loss: 0.1963
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.7993e-04 - val_loss: 0.1200
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0220e-04 - val_loss: 0.1719
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0118e-04 - val_loss: 0.1325
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3507e-04 - val_loss: 0.1288
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1010e-04 - val_loss: 0.1146
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4157e-04 - val_loss: 0.1758
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.3201e-04 - val_loss: 0.1393
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1468e-04 - val_loss: 0.0719
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9101e-04 - val_loss: 0.1095
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.0041e-04 - val_loss: 0.1175
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2011e-04 - val_loss: 0.0561
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3474e-04 - val_loss: 0.0479
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6971e-04 - val_loss: 0.0573
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3224e-04 - val_loss: 0.0596
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5991e-04 - val_loss: 0.0407
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9724e-04 - val_loss: 0.0435
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.7011e-04 - val_loss: 0.0593
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.6523e-04 - val_loss: 0.0596
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6170e-04 - val_loss: 0.0352
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4598e-04 - val_loss: 0.0361
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2830e-04 - val_loss: 0.0227
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5859e-04 - val_loss: 0.0473
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6959e-04 - val_loss: 0.0436
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6121e-04 - val_loss: 0.0575
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.3638e-04 - val_loss: 0.0435
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1118e-04 - val_loss: 0.0252
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 4.0276e-04 - val_loss: 0.0436
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4004e-04 - val_loss: 0.0278
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.0309e-04 - val_loss: 0.0255
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6271e-04 - val_loss: 0.0387
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.2191e-04 - val_loss: 0.0406
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4750e-04 - val_loss: 0.0405
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1048e-04 - val_loss: 0.0281
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9997e-04 - val_loss: 0.0422
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.1925e-04 - val_loss: 0.0319
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.7529e-04 - val_loss: 0.0314
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.1298e-04 - val_loss: 0.0471
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.4717e-04 - val_loss: 0.0395
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5029e-04 - val_loss: 0.0206
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4469e-04 - val_loss: 0.0261
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3663e-04 - val_loss: 0.0355
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0294e-04 - val_loss: 0.0248
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.2512e-04 - val_loss: 0.0373
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9414e-04 - val_loss: 0.0421
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1253e-04 - val_loss: 0.0321
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3351e-04 - val_loss: 0.0301
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4871e-04 - val_loss: 0.0143
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2738e-04 - val_loss: 0.0219
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0699e-04 - val_loss: 0.0247
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9085e-04 - val_loss: 0.0223
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2586e-04 - val_loss: 0.0182
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0489e-04 - val_loss: 0.0281
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1273e-04 - val_loss: 0.0499
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1110e-04 - val_loss: 0.0248
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Train MAE: 2.5343, Train MSE: 12.4933, Train RMSE: 3.5346, Train R²: 0.9542
# Test MAE: 26.5181, Test MSE: 758.4694, Test RMSE: 27.5403, Test R²: -0.7206
